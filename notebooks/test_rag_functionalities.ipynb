# %%
pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.0-cp39-abi3-macosx_14_0_arm64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 1.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/oussamayousr/Documents/ai-agent-multimodal-rag/ai-env/lib/python3.9/site-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /Users/oussamayousr/Documents/ai-agent-multimodal-rag/ai-env/lib/python3.9/site-packages (from faiss-cpu) (25.0)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.0
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/oussamayousr/Documents/ai-agent-multimodal-rag/ai-env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import faiss
import numpy as np

# Distance L2
d = 128  # dimension des vecteurs
index_l2 = faiss.IndexFlatL2(d)
print(type(index_l2))
# Produit scalaire
index_ip = faiss.IndexFlatIP(d)
# Out:
# <class 'faiss.swigfaiss.IndexFlatL2'>

# %%
def foo():
    print(*[1, 2, 3])
foo(  )
# Out:
# 1 2 3

# %%
# Out:
# 'oussama yousr'
